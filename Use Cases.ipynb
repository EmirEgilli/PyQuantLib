# %% [markdown]
# # PYQuantLib

# %% [markdown]
# ## A library of some of the functions i most commonly use. Planning on frequent updates.

# %%
# Import Library
import PyQuantLib as PQL

# %% [markdown]
# ## For Single Assets:

# %%
PQL.MonteCarlo("BZ=F")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
PQL.VaR("BZ=F")
# Out:
# [*********************100%***********************]  1 of 1 completed
# +------------------+---------------+-------------+
# | Confidence Level | Value at Risk | Price Range |
# +------------------+---------------+-------------+
# |       90%        |    -0.0273    |   74.5185   |
# |       95%        |    -0.0403    |   73.5226   |
# |       99%        |    -0.0677    |   71.4235   |
# +------------------+---------------+-------------+

# %% [markdown]
# ## For Stock Portfolios:

# %%
PQL.StocksAnalyze("MA, IBM, XOM, KO, LMT", start="2018-01-01")
# Out:
# [*********************100%***********************]  5 of 5 completed

# %% [markdown]
# ### We can then run an Efficient Frontier with 10000 allocations:

# %%
PQL.markowitz("MA, IBM, XOM, KO, LMT", "2018-01-01")
# Out:
# Optimal portfolio:  [0.56  0.    0.    0.283 0.157]
# Expected return, volatility and Sharpe ratio:  [0.13592172 0.24203237 0.56158487]

# %% [markdown]
# ### Since some stocks are given zero weights, let's run a Two-Fund Efficient Frontier to check for shorting opportunities and see if it improves the Sharpe ratio

# %%
PQL.TFEF("MA, IBM, XOM, KO, LMT", "2021-01-01")
# Out:
# OrderedDict([(0, -0.07294), (1, 0.11772), (2, 0.26965), (3, 0.49714), (4, 0.18843)])
# Expected annual return: 20.0%
# Annual volatility: 15.7%
# Sharpe Ratio: 1.15
# OrderedDict([(0, -0.18733), (1, 0.06232), (2, 0.49719), (3, 0.47053), (4, 0.15729)])
# Expected annual return: 28.0%
# Annual volatility: 19.4%
# Sharpe Ratio: 1.34

# %% [markdown]
# ### Additional verification with Capital Asset Pricing Model (CAPM) to see expected returns in shorter term

# %%
PQL.CAPM("MA, IBM, XOM, KO, LMT", "2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Beta from formula:  0.47340206374320476
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Beta from regression:  0.4734008496977233
# Expected Return:  0.08089638911069043

# %% [markdown]
# ### Finally, let's check our Sharpe ratio if we would use different weights than TFEF

# %%
PQL.PortSharpe({'MA': 0.06, 'IBM': 0.14, 'XOM': 0.25, 'KO': 0.15, 'LMT': 0.40}, start="2021-01-01", market="US")
# Out:
# [*********************100%***********************]  5 of 5 completed
#  Sharpe Ratio for Portfolio: 1.25
#  Annual Volatility: 18.69 %
#  Expected Annual Returns: 23.33 %
